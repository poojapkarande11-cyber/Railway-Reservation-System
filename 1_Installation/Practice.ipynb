# %%
print ("Hello world")
# Out:
# Hello world

# %%
name = "pooja"
age = 30
price = 25.99

# %%
print( "name")
print(name)
print( age)
print(price)
# Out:
# name
# pooja
# 30
# 25.99

# %%
print(type(name))
print(type(age))
print(type(price))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
## sum

a = 10
b = 20
sum = a + b
print(sum)
print(a + b)
# Out:
# 30
# 30

# %%
## type casting

a , b = 1 , "2"
c = int(b)
sum = a + c
print(sum)
# Out:
# 3

# %%
age =23
old = True
a = None
print(type(old))
print(type(a))
# Out:
# <class 'bool'>
# <class 'NoneType'>

# %%
## arITHmetice operator

a = 5
b= 2

print ( a + b)
print ( a - b)
print ( a * b)
print ( a / b)
print ( a ** b) 
print ( a % b)
# Out:
# 7
# 3
# 10
# 2.5
# 25
# 1

# %%
## comparision operator / Relational operator

a = 50
b = 20

print( a == b) ## == means is equal to
print( a != b) ## != not equal to
# Out:
# False
# True
