# %%
y =lambda x,z: print(x / z)
y(8,4)
# Out:
# 2.0

# %%
a = float(input("enter your price"))
discount = (a/100)*20
y = lambda x: print(x - discount)
y(a)
# Out:
# 12000.0

# %%
fare = [ 2500 ,3000, 3500, 4000, 4500]

updated_fare = list(map(lambda x: x - (x * 0.2), fare))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 updated_fares = list( 100 ,200 ,300 ,400 ,500)
#       2
#       3 map(lambda fare: fare + 100, updated_fares)
#       4
#
# TypeError: list expected at most 1 argument, got 5
