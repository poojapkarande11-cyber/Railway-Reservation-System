# %% [markdown]
# LAB 3

# %% [markdown]
# Task 1 :store passenger Details using variables

# %%
passanger_name= "Rohit Sharma"
passanger_age = 28
gender= "Male"
mobile_number = 9876543210

# %%
print("passanger name:", passanger_name)
print("passanger age:", passanger_age)
print("Gender:", gender)
print ("Mobile number:", mobile_number)
# Out:
# passanger name: Rohit Sharma
# passanger age: 28
# Gender: Male
# Mobile number: 9876543210

# %% [markdown]
# Task 2 store ticket price and seat Number

# %%
train_name = "Rajdhani Express"
seat_number = "B2-45"
ticket_price =2450
journey_date = "25-May-2026"

# %%
print("train name:",train_name)
print("Seat Number:", seat_number)
print("Ticekt Price:", ticket_price)
print("Journey Date:", journey_date)
# Out:
# train name: Rajdhani Express
# Seat Number: B2-45
# Ticekt Price: 2450
# Journey Date: 25-May-2026

# %%
##input Function +implicit typecasting
passanger_name = input("Enter your name")
print(passanger_name)
type(passanger_name)
# Out:
# str

# %%
# # Input Function + Explicit typecasting
Ticket_price = int(input("enter price of ticket"))
print(type(Ticket_price))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 # # Input Function + Explicit typecasting
# ----> 2 Ticket_price = int(input("enter price of ticket"))
#       3 print(type(Ticket_price))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
## task 3: Perform Ticket Fare Calculations

number_of_passanger = 3
ticket_price = 2450

# %%
total_fare = number_of_passanger * ticket_price
print("total fare :", total_fare)
# Out:
# total fare : 7350

# %%
## task 4 :Calculate GST on Ticket Fare

gst_percentage = 5

# %%
gst_amount = (total_fare * gst_percentage) / 100
print("GST Amount:", gst_amount)
# Out:
# GST Amount: 367.5

# %%
a =(1,2,3,1,3,1,1,4)
a = set(a)
print(a)
# Out:
# {1, 2, 3, 4}

# %%
age = int(input("Enter your age:"))

if age >= 18:
    print("person is eligible for voting")
else:
    print( "person is not eligible for voting")
# Out:
# person is eligible for voting

# %%
credit_score = int(input( "Enter credit score:"))
income = float(input("Enter income:"))
loan_amount = float(input("enter loan amount "))

if credit_score >= 700 and income >= 2 *loan_amount:
    print("Approved")
else:
    print("Denied")
# Out:
# Approved
