# %%
## Task 1: Store Train Data Using Dictionaries

train = {
    "Train_Number": 12951,
    "Train_Name": "Mumbai Rajdhani Express",
    "Source": "Mumbai",
    "Destination": "Delhi",
    "Available_Seats": 120
}

# %%
print("Train Information:")
print(train)

print("\nTrain Number:", train["Train_Number"])
print("Train Name:", train["Train_Name"])
print("Source Station:", train["Source"])
print("Destination Station:", train["Destination"])
print("Available Seats:", train["Available_Seats"])
# Out:
# Train Information:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Source': 'Mumbai', 'Destination': 'Delhi', 'Available_Seats': 120}
#
# Train Number: 12951
# Train Name: Mumbai Rajdhani Express
# Source Station: Mumbai
# Destination Station: Delhi
# Available Seats: 120

# %%
## Task 2: Access and Update Values


train = {
    "Train_Number": 12951,
    "Train_name": "Mumbai Rajdhani Express",
    "Available_seats":  120
}

# %%
print(train)
# Out:
# {'Train_Number': 12951, 'Train_name': 'Mumbai Rajdhani Express', 'Available_seats': 120}

# %%
## Access Dictionary Values

print("Train Name:", train["Train_name"])
print("Available Seats:", train["Available_seats"])
# Out:
# Train Name: Mumbai Rajdhani Express
# Available Seats: 120

# %%
## Update Seat Availability


train["Available_Seats"] = 95
print(train)
# Out:
# {'Train_Number': 12951, 'Train_name': 'Mumbai Rajdhani Express', 'Available_seats': 120, 'Available_Seats': 95}

# %%
## Add New Value Using update()

train.update({"Platform": 4})
print(train)
# Out:
# {'Train_Number': 12951, 'Train_name': 'Mumbai Rajdhani Express', 'Available_seats': 120, 'Available_Seats': 95, 'Platform': 4}

# %%
##Remove Value Using pop()

train.pop("Platform")
print(train)
# Out:
# {'Train_Number': 12951, 'Train_name': 'Mumbai Rajdhani Express', 'Available_seats': 120, 'Available_Seats': 95}

# %%
##Display Updated Dictionary
print("\nUpdated Train Record")
print(train)
# Out:
# Updated Train Record
# {'Train_Number': 12951, 'Train_name': 'Mumbai Rajdhani Express', 'Available_seats': 120, 'Available_Seats': 95}

# %%
chintu_dict= {}
num = int(input("Enter lenght of dict"))

for i in range(num):
    key = input("enter key")
    value = input("enter value")
    chintu_dict.update({key:value})

  chintu_dict
# Out:
#   File <string>:9
#     chintu_dict
#                ^
# IndentationError: unindent does not match any outer indentation level
