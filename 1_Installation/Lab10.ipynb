# %%
#121 = 1+2+1= 4
#440 = 4+4+0 =8


a = input("Enter your Number")
out = 0
for i in a:
    out = out + int(i)
print(out)
# Out:
# 8

# %%
#Itvedant
a= input("Enter your name").lower()
if a[0] in "aeiou":
    print("an")
else:
    prnt("a")
# Out:
# an
