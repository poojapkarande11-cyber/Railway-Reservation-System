# %% [markdown]
# Creating variable for Railway information

# %%
train_name = "Rajdhani Express" 
train_number = 12951
source_station = "Mumbai"
destination_station = "Delhi"
ticket_price = 2450.75

# %%
print("welcome to Indian Railway Resrvation System")
print("Train Name:", train_name)
print("Train Number:", train_number)
print("Source Station:", source_station)
print("Destination Station:", destination_station)
# Out:
# welcome to Indian Railway Resrvation System
# Train Name: Rajdhani Express
# Train Number: 12951
# Source Station: Mumbai
# Destination Station: Delhi

# %%
print(type(train_name))
print(type(train_number))
print(type(ticket_price))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# task: identifies and literals

# %%
passanger_name = "Rahul Sharma"
seat_number = "B2-45"
is_confirmed = True

# %%
ticket_price_integer = int(ticket_price)
print(type(ticket_price_integer))
# Out:
# <class 'int'>

# %%
train_number_str = str(train_number)
print(type(train_number_str))
# Out:
# <class 'str'>
