# %% [markdown]
# Conditional Statements

# %%
## task 1 :  Build a Basic Ticket Status Checker
passanger_name = "rahul sharma"
ticket_Status = "confirmed"

# %%
if ticket_Status == "confirmed":
    print("ticket is confirmed")
# Out:
# ticket is confirmed

# %%
## task 2 : Apply If...Else Statement for Ticket Verification
waiting_list = 3

# %%
if waiting_list == 0:
    print ( "ticket is confirmed")
else:
    print ( "ticket is in waiting list")
# Out:
# ticket is in waiting list

# %%
ticket_status_NEW = "RAC"

# %%
# ticket_status = input("Enter your ticket status:")
if ticket_status_NEW == "confirmed":
    print("seat alloacted successfully")
elif ticket_status_NEW == "RAC":
    print("partial reservation available")
else:
    print("ticket is in waiting list")
# Out:
# partial reservation available

# %% [markdown]
# Task 4: Understanding Indentation in Python

# %%
age = 65
if age >= 65 :
    print("Passanger Eligible for senior Citizen Discount")
# Out:
# Passanger Eligible for senior Citizen Discount

# %% [markdown]
# Task 5: Apply Logical Operators in Railway System

# %%
##Create passenger age and booking status variables


age = 65
is_ticket_confirmation = True

# %%
## Create passenger age and booking status variables

if age >= 60 and is_ticket_confirmation == True:
    print("Passanger Eligible for senior Citizen Benefits")
# Out:
# Passanger Eligible for senior Citizen Benefits

# %% [markdown]
# Task 6: Build Final Railway Ticket Validation System

# %%
## Create passenger and payment details


ticket_status = "confirmed"
payment_status = "Paid"

# %%
IF ticket_Status ==
